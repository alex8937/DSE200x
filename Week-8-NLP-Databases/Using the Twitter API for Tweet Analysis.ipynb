# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.17.1

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000002778484F400>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2017-08-20T02:15:43Z',
#   'created_at': '2017-08-20T02:07:08Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#NXTTakeOver',
#     'promoted_content': None,
#     'query': '%23NXTTakeOver',
#     'tweet_volume': 116473,
#     'url': 'http://twitter.com/search?q=%23NXTTakeOver'},
#    {'name': '#MissBrasil',
#     'promoted_content': None,
#     'query': '%23MissBrasil',
#     'tweet_volume': 12585,
#     'url': 'http://twitter.com/search?q=%23MissBrasil'},
#    {'name': '#CriancaEsperanca',
#     'promoted_content': None,
#     'query': '%23CriancaEsperanca',
#     'tweet_volume': 27861,
#     'url': 'http://twitter.com/search?q=%23CriancaEsperanca'},
#    {'name': '#Luan10',
#     'promoted_content': None,
#     'query': '%23Luan10',
#     'tweet_volume': 74447,
#     'url': 'http://twitter.com/search?q=%23Luan10'},
#    {'name': '#BakeOffBrasil',
#     'promoted_content': None,
#     'query': '%23BakeOffBrasil',
#     'tweet_volume': 11889,
#     'url': 'http://twitter.com/search?q=%23BakeOffBrasil'},
#    {'name': 'Guede',
#     'promoted_content': None,
#     'query': 'Guede',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Guede'},
#    {'name': 'Dick Gregory',
#     'promoted_content': None,
#     'query': '%22Dick+Gregory%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Dick+Gregory%22'},
#    {'name': 'Corinthians',
#     'promoted_content': None,
#     'query': 'Corinthians',
#     'tweet_volume': 121807,
#     'url': 'http://twitter.com/search?q=Corinthians'},
#    {'name': '設営完了',
#     'promoted_content': None,
#     'query': '%E8%A8%AD%E5%96%B6%E5%AE%8C%E4%BA%86',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E8%A8%AD%E5%96%B6%E5%AE%8C%E4%BA%86'},
#    {'name': 'Cooper Rush',
#     'promoted_content': None,
#     'query': '%22Cooper+Rush%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Cooper+Rush%22'},
#    {'name': 'Wilmar',
#     'promoted_content': None,
#     'query': 'Wilmar',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Wilmar'},
#    {'name': 'Pumas',
#     'promoted_content': None,
#     'query': 'Pumas',
#     'tweet_volume': 16380,
#     'url': 'http://twitter.com/search?q=Pumas'},
#    {'name': 'Vinicius Jr',
#     'promoted_content': None,
#     'query': '%22Vinicius+Jr%22',
#     'tweet_volume': 52259,
#     'url': 'http://twitter.com/search?q=%22Vinicius+Jr%22'},
#    {'name': 'Dolphin Mall',
#     'promoted_content': None,
#     'query': '%22Dolphin+Mall%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Dolphin+Mall%22'},
#    {'name': 'Fabra',
#     'promoted_content': None,
#     'query': 'Fabra',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Fabra'},
#    {'name': 'Cruz Azul',
#     'promoted_content': None,
#     'query': '%22Cruz+Azul%22',
#     'tweet_volume': 24441,
#     'url': 'http://twitter.com/search?q=%22Cruz+Azul%22'},
#    {'name': 'Mancini',
#     'promoted_content': None,
#     'query': 'Mancini',
#     'tweet_volume': 21261,
#     'url': 'http://twitter.com/search?q=Mancini'},
#    {'name': 'Cerro',
#     'promoted_content': None,
#     'query': 'Cerro',
#     'tweet_volume': 36322,
#     'url': 'http://twitter.com/search?q=Cerro'},
#    {'name': 'Arrogate',
#     'promoted_content': None,
#     'query': 'Arrogate',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Arrogate'},
#    {'name': 'コミティア',
#     'promoted_content': None,
#     'query': '%E3%82%B3%E3%83%9F%E3%83%86%E3%82%A3%E3%82%A2',
#     'tweet_volume': 50778,
#     'url': 'http://twitter.com/search?q=%E3%82%B3%E3%83%9F%E3%83%86%E3%82%A3%E3%82%A2'},
#    {'name': 'Jaylon Smith',
#     'promoted_content': None,
#     'query': '%22Jaylon+Smith%22',
#     'tweet_volume': 10967,
#     'url': 'http://twitter.com/search?q=%22Jaylon+Smith%22'},
#    {'name': 'インテ',
#     'promoted_content': None,
#     'query': '%E3%82%A4%E3%83%B3%E3%83%86',
#     'tweet_volume': 73387,
#     'url': 'http://twitter.com/search?q=%E3%82%A4%E3%83%B3%E3%83%86'},
#    {'name': 'Barroso',
#     'promoted_content': None,
#     'query': 'Barroso',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Barroso'},
#    {'name': 'Stage 1',
#     'promoted_content': None,
#     'query': '%22Stage+1%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Stage+1%22'},
#    {'name': 'Colts',
#     'promoted_content': None,
#     'query': 'Colts',
#     'tweet_volume': 13155,
#     'url': 'http://twitter.com/search?q=Colts'},
#    {'name': '#مزاجي_يبي_الان',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%B2%D8%A7%D8%AC%D9%8A_%D9%8A%D8%A8%D9%8A_%D8%A7%D9%84%D8%A7%D9%86',
#     'tweet_volume': 46842,
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%B2%D8%A7%D8%AC%D9%8A_%D9%8A%D8%A8%D9%8A_%D8%A7%D9%84%D8%A7%D9%86'},
#    {'name': '#لو_التقاليد_والعادات_تسمح_لي',
#     'promoted_content': None,
#     'query': '%23%D9%84%D9%88_%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D9%84%D9%8A%D8%AF_%D9%88%D8%A7%D9%84%D8%B9%D8%A7%D8%AF%D8%A7%D8%AA_%D8%AA%D8%B3%D9%85%D8%AD_%D9%84%D9%8A',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D9%84%D9%88_%D8%A7%D9%84%D8%AA%D9%82%D8%A7%D9%84%D9%8A%D8%AF_%D9%88%D8%A7%D9%84%D8%B9%D8%A7%D8%AF%D8%A7%D8%AA_%D8%AA%D8%B3%D9%85%D8%AD_%D9%84%D9%8A'},
#    {'name': '#LugaresQueHablan',
#     'promoted_content': None,
#     'query': '%23LugaresQueHablan',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LugaresQueHablan'},
#    {'name': '#LaNocheDeML',
#     'promoted_content': None,
#     'query': '%23LaNocheDeML',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LaNocheDeML'},
#    {'name': '#PodemosHablar',
#     'promoted_content': None,
#     'query': '%23PodemosHablar',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PodemosHablar'},
#    {'name': '#BOCAxESPN',
#     'promoted_content': None,
#     'query': '%23BOCAxESPN',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BOCAxESPN'},
#    {'name': '#راعي_لكزس_يستعرض_بمخموره',
#     'promoted_content': None,
#     'query': '%23%D8%B1%D8%A7%D8%B9%D9%8A_%D9%84%D9%83%D8%B2%D8%B3_%D9%8A%D8%B3%D8%AA%D8%B9%D8%B1%D8%B6_%D8%A8%D9%85%D8%AE%D9%85%D9%88%D8%B1%D9%87',
#     'tweet_volume': 43091,
#     'url': 'http://twitter.com/search?q=%23%D8%B1%D8%A7%D8%B9%D9%8A_%D9%84%D9%83%D8%B2%D8%B3_%D9%8A%D8%B3%D8%AA%D8%B9%D8%B1%D8%B6_%D8%A8%D9%85%D8%AE%D9%85%D9%88%D8%B1%D9%87'},
#    {'name': '#HispanicsBreakTheInternet',
#     'promoted_content': None,
#     'query': '%23HispanicsBreakTheInternet',
#     'tweet_volume': 121265,
#     'url': 'http://twitter.com/search?q=%23HispanicsBreakTheInternet'},
#    {'name': '#زواج_حمود_الفايز_وروي_الصبان',
#     'promoted_content': None,
#     'query': '%23%D8%B2%D9%88%D8%A7%D8%AC_%D8%AD%D9%85%D9%88%D8%AF_%D8%A7%D9%84%D9%81%D8%A7%D9%8A%D8%B2_%D9%88%D8%B1%D9%88%D9%8A_%D8%A7%D9%84%D8%B5%D8%A8%D8%A7%D9%86',
#     'tweet_volume': 119707,
#     'url': 'http://twitter.com/search?q=%23%D8%B2%D9%88%D8%A7%D8%AC_%D8%AD%D9%85%D9%88%D8%AF_%D8%A7%D9%84%D9%81%D8%A7%D9%8A%D8%B2_%D9%88%D8%B1%D9%88%D9%8A_%D8%A7%D9%84%D8%B5%D8%A8%D8%A7%D9%86'},
#    {'name': '#SignsYoureOutOfTouch',
#     'promoted_content': None,
#     'query': '%23SignsYoureOutOfTouch',
#     'tweet_volume': 10198,
#     'url': 'http://twitter.com/search?q=%23SignsYoureOutOfTouch'},
#    {'name': '#MostRequestedLive',
#     'promoted_content': None,
#     'query': '%23MostRequestedLive',
#     'tweet_volume': 63655,
#     'url': 'http://twitter.com/search?q=%23MostRequestedLive'},
#    {'name': '#يابشر_ملينا',
#     'promoted_content': None,
#     'query': '%23%D9%8A%D8%A7%D8%A8%D8%B4%D8%B1_%D9%85%D9%84%D9%8A%D9%86%D8%A7',
#     'tweet_volume': 10868,
#     'url': 'http://twitter.com/search?q=%23%D9%8A%D8%A7%D8%A8%D8%B4%D8%B1_%D9%85%D9%84%D9%8A%D9%86%D8%A7'},
#    {'name': '#PushAwardsKathNiels',
#     'promoted_content': None,
#     'query': '%23PushAwardsKathNiels',
#     'tweet_volume': 144166,
#     'url': 'http://twitter.com/search?q=%23PushAwardsKathNiels'},
#    {'name': '#LaLigaTVN',
#     'promoted_content': None,
#     'query': '%23LaLigaTVN',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LaLigaTVN'},
#    {'name': '#LaNuevaOlla',
#     'promoted_content': None,
#     'query': '%23LaNuevaOlla',
#     'tweet_volume': 22023,
#     'url': 'http://twitter.com/search?q=%23LaNuevaOlla'},
#    {'name': '#TFCLive',
#     'promoted_content': None,
#     'query': '%23TFCLive',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TFCLive'},
#    {'name': '#ワイドナショー',
#     'promoted_content': None,
#     'query': '%23%E3%83%AF%E3%82%A4%E3%83%89%E3%83%8A%E3%82%B7%E3%83%A7%E3%83%BC',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E3%83%AF%E3%82%A4%E3%83%89%E3%83%8A%E3%82%B7%E3%83%A7%E3%83%BC'},
#    {'name': '#DaleAlboAlaCancha',
#     'promoted_content': None,
#     'query': '%23DaleAlboAlaCancha',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DaleAlboAlaCancha'},
#    {'name': '#نواف_العابد',
#     'promoted_content': None,
#     'query': '%23%D9%86%D9%88%D8%A7%D9%81_%D8%A7%D9%84%D8%B9%D8%A7%D8%A8%D8%AF',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D9%86%D9%88%D8%A7%D9%81_%D8%A7%D9%84%D8%B9%D8%A7%D8%A8%D8%AF'},
#    {'name': '#بالروح_ياهلال_العين_مايروح',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D8%A7%D9%84%D8%B1%D9%88%D8%AD_%D9%8A%D8%A7%D9%87%D9%84%D8%A7%D9%84_%D8%A7%D9%84%D8%B9%D9%8A%D9%86_%D9%85%D8%A7%D9%8A%D8%B1%D9%88%D8%AD',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D8%A7%D9%84%D8%B1%D9%88%D8%AD_%D9%8A%D8%A7%D9%87%D9%84%D8%A7%D9%84_%D8%A7%D9%84%D8%B9%D9%8A%D9%86_%D9%85%D8%A7%D9%8A%D8%B1%D9%88%D8%AD'},
#    {'name': '#GBvsWAS',
#     'promoted_content': None,
#     'query': '%23GBvsWAS',
#     'tweet_volume': 11079,
#     'url': 'http://twitter.com/search?q=%23GBvsWAS'},
#    {'name': '#L6Nnotengomiedo',
#     'promoted_content': None,
#     'query': '%23L6Nnotengomiedo',
#     'tweet_volume': 14639,
#     'url': 'http://twitter.com/search?q=%23L6Nnotengomiedo'},
#    {'name': '#LosFinesSiempre',
#     'promoted_content': None,
#     'query': '%23LosFinesSiempre',
#     'tweet_volume': 63959,
#     'url': 'http://twitter.com/search?q=%23LosFinesSiempre'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#NXTTakeOver', 'url': 'http://twitter.com/search?q=%23NXTTakeOver', 'promoted_content': None, 'query': '%23NXTTakeOver', 'tweet_volume': 117828}, {'name': 'Pacific Classic', 'url': 'http://twitter.com/search?q=%22Pacific+Classic%22', 'promoted_content': None, 'query': '%22Pacific+Classic%22', 'tweet_volume': None}, {'name': '#HispanicsBreakTheInternet', 'url': 'http://twitter.com/search?q=%23HispanicsBreakTheInternet', 'promoted_content': None, 'query': '%23HispanicsBreakTheInternet', 'tweet_volume': 121958}, {'name': '#NW88JR', 'url': 'http://twitter.com/search?q=%23NW88JR', 'promoted_content': None, 'query': '%23NW88JR', 'tweet_volume': None}, {'name': '#D6Toss', 'url': 'http://twitter.com/search?q=%23D6Toss', 'promoted_content': None, 'query': '%23D6Toss', 'tweet_volume': None}, {'name': '#eclipse', 'url': 'http://twitter.com/search?q=%23eclipse', 'promoted_content': None, 'query': '%23eclipse', 'tweet_volume': 22539}, {'name': 'Dick Gregory', 'url': 'http://twitter.com/search?q=%22Dick+Gregory%22', 'promoted_content': None, 'query': '%22Dick+Gregory%22', 'tweet_volume': None}, {'name': 'Cooper Rush', 'url': 'http://twitter.com/search?q=%22Cooper+Rush%22', 'promoted_content': None, 'query': '%22Cooper+Rush%22', 'tweet_volume': None}, {'name': 'Dolphin Mall', 'url': 'http://twitter.com/search?q=%22Dolphin+Mall%22', 'promoted_content': None, 'query': '%22Dolphin+Mall%22', 'tweet_volume': None}, {'name': 'Colts', 'url': 'http://twitter.com/search?q=Colts', 'promoted_content': None, 'query': 'Colts', 'tweet_volume': 13352}, {'name': 'Rex Burkhead', 'url': 'http://twitter.com/search?q=%22Rex+Burkhead%22', 'promoted_content': None, 'query': '%22Rex+Burkhead%22', 'tweet_volume': None}, {'name': 'Noah Brown', 'url': 'http://twitter.com/search?q=%22Noah+Brown%22', 'promoted_content': None, 'query': '%22Noah+Brown%22', 'tweet_volume': None}, {'name': 'Marlon Mack', 'url': 'http://twitter.com/search?q=%22Marlon+Mack%22', 'promoted_content': None, 'query': '%22Marlon+Mack%22', 'tweet_volume': None}, {'name': 'Stephen Morris', 'url': 'http://twitter.com/search?q=%22Stephen+Morris%22', 'promoted_content': None, 'query': '%22Stephen+Morris%22', 'tweet_volume': None}, {'name': 'Tyler Austin', 'url': 'http://twitter.com/search?q=%22Tyler+Austin%22', 'promoted_content': None, 'query': '%22Tyler+Austin%22', 'tweet_volume': None}, {'name': 'Mahomes', 'url': 'http://twitter.com/search?q=Mahomes', 'promoted_content': None, 'query': 'Mahomes', 'tweet_volume': None}, {'name': 'Bruce Ellington', 'url': 'http://twitter.com/search?q=%22Bruce+Ellington%22', 'promoted_content': None, 'query': '%22Bruce+Ellington%22', 'tweet_volume': None}, {'name': 'Andre Hal', 'url': 'http://twitter.com/search?q=%22Andre+Hal%22', 'promoted_content': None, 'query': '%22Andre+Hal%22', 'tweet_volume': None}, {'name': 'Tom Savage', 'url': 'http://twitter.com/search?q=%22Tom+Savage%22', 'promoted_content': None, 'query': '%22Tom+Savage%22', 'tweet_volume': None}, {'name': 'Hackenberg', 'url': 'http://twitter.com/search?q=Hackenberg', 'promoted_content': None, 'query': 'Hackenberg', 'tweet_volume': None}, {'name': 'Ross Martin', 'url': 'http://twitter.com/search?q=%22Ross+Martin%22', 'promoted_content': None, 'query': '%22Ross+Martin%22', 'tweet_volume': None}, {'name': 'Aaron Rodgers', 'url': 'http://twitter.com/search?q=%22Aaron+Rodgers%22', 'promoted_content': None, 'query': '%22Aaron+Rodgers%22', 'tweet_volume': None}, {'name': 'USS Indianapolis', 'url': 'http://twitter.com/search?q=%22USS+Indianapolis%22', 'promoted_content': None, 'query': '%22USS+Indianapolis%22', 'tweet_volume': 19595}, {'name': 'Cyrus Jones', 'url': 'http://twitter.com/search?q=%22Cyrus+Jones%22', 'promoted_content': None, 'query': '%22Cyrus+Jones%22', 'tweet_volume': None}, {'name': 'Denard Span', 'url': 'http://twitter.com/search?q=%22Denard+Span%22', 'promoted_content': None, 'query': '%22Denard+Span%22', 'tweet_volume': None}, {'name': 'Chris Thompson', 'url': 'http://twitter.com/sea ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#NXTTakeOver",
#     "url": "http://twitter.com/search?q=%23NXTTakeOver",
#     "promoted_content": null,
#     "query": "%23NXTTakeOver",
#     "tweet_volume": 119678
#    },
#    {
#     "name": "Dick Gregory",
#     "url": "http://twitter.com/search?q=%22Dick+Gregory%22",
#     "promoted_content": null,
#     "query": "%22Dick+Gregory%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cooper Rush",
#     "url": "http://twitter.com/search?q=%22Cooper+Rush%22",
#     "promoted_content": null,
#     "query": "%22Cooper+Rush%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SignsYoureOutOfTouch",
#     "url": "http://twitter.com/search?q=%23SignsYoureOutOfTouch",
#     "promoted_content": null,
#     "query": "%23SignsYoureOutOfTouch",
#     "tweet_volume": 10776
#    },
#    {
#     "name": "Dolphin Mall",
#     "url": "http://twitter.com/search?q=%22Dolphin+Mall%22",
#     "promoted_content": null,
#     "query": "%22Dolphin+Mall%22",
#     "tweet_volume": 11015
#    },
#    {
#     "name": "#HispanicsBreakTheInternet",
#     "url": "http://twitter.com/search?q=%23HispanicsBreakTheInternet",
#     "promoted_content": null,
#     "query": "%23HispanicsBreakTheInternet",
#     "tweet_volume": 122597
#    },
#    {
#     "name": "#MostRequestedLive",
#     "url": "http://twitter.com/search?q=%23MostRequestedLive",
#     "promoted_content": null,
#     "query": "%23MostRequestedLive",
#     "tweet_volume": 64700
#    },
#    {
#     "name": "#CrawfordIndongo",
#     "url": "http://twitter.com/search?q=%23CrawfordIndongo",
#     "promoted_content": null,
#     "query": "%23CrawfordIndongo",
#     "tweet_volume": null
#    },
#    {
#     "name": "Stage 2",
#     "url": "http://twitter.com/search?q=%22Stage+2%22",
#     "promoted_content": null,
#     "query": "%22Stage+2%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Colts",
#     "url": "http://twitter.com/search?q=Colts",
#     "promoted_content": null,
#     "query": "Colts",
#     "tweet_volume": 13504
#    },
#    {
#     "name": "Arrogate",
#     "url": "http://twitter.com/search?q=Arrogate",
#     "promoted_content": null,
#     "query": "Arrogate",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rex Burkhead",
#     "url": "http://twitter.com/search?q=%22Rex+Burkhead%22",
#     "promoted_content": null,
#     "query": "%22Rex+Burkhead%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Noah Brown",
#     "url": "http://twitter.com/search?q=%22Noah+Brown%22",
#     "promoted_content": null,
#     "query": "%22Noah+Brown%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Marlon Mack",
#     "url": "http://twitter.com/search?q=%22Marlon+Mack%22",
#     "promoted_content": null,
#     "query": "%22Marlon+Mack%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Stephen Morris",
#     "url": "http://twitter.com/search?q=%22Stephen+Morris%22",
#     "promoted_content": null,
#     "query": "%22Stephen+Morris%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tyler Austin",
#     "url": "http://twitter.com/search?q=%22Tyler+Austin%22",
#     "promoted_content": null,
#     "query": "%22Tyler+Austin%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mahomes",
#     "url": "http://twitter.com/search?q=Mahomes",
#     "promoted_content": null,
#     "query": "Mahomes",
#     "tweet_volume": null
#    },
#    {
#     "name": "Andre Hal",
#     "url": "http://twitter.com/search?q=%22Andre+Hal%22",
#     "promoted_content": null,
#     "query": "%22Andre+Hal%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Shakur Stevenson",
#     "url": "http://twitter.com/search?q=%22Shakur+Stevenson%22",
#     "promoted_content": null,
#     "query": "%22Shakur+Stevenson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tom Savage",
#     "url": "http://twitter.com/search?q=%22Tom+Savage%22",
#     "promoted_content": null,
#     "query": "%22Tom+Savage%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hackenberg",
#     "url": "http://twitter.com/search?q=Hackenberg",
#     "promoted_content": null,
#     "query": "Hackenberg",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cyrus Jones",
#     "url": "http://twitter.com/search?q=%22Cyrus+Jones%22",
#     "promoted_content": null,
#     "query": "%22Cyrus+Jones%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ross Martin",
#     "url": "http://twitter.com/search?q=%22Ross+Martin%22",
#     "promoted_content": null,
#     "query": "%22Ross+Martin%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Devers",
#     "url": "http://twitter.com/search?q=Devers",
#     "promoted_content": null,
#     "query": "Devers",
#     "tweet_volume": null
#    },
#    {
#     "name": "Aaron Rodgers",
#     "url": "http://twitter.com/search?q=%22Aaron+Rodgers%22",
#     "promoted_content": null,
#     "query": "%22Aaron+Rodgers%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "D'Onta Foreman",
#     "url": "http://twitter.com/search?q=%22D%27Onta+Foreman%22",
#     "promoted_content": null,
#     "query": "%22D%27Onta+Foreman%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "USS Indianapolis",
#     "url": "http://twitter.com/search?q=%22USS+Indianapolis%22",
#     "promoted_content": null,
#     "query": "%22USS+Indianapolis%22",
#     "tweet_volume": 19789
#    },
#    {
#     "name": "Bruce Ellington",
#     "url": "http://twitter.com/search?q=%22Bruce+Ellington%22",
#     "promoted_content": null,
#     "query": "%22Bruce+Ellington%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Elandon Roberts",
#     "url": "http://twitter.com/search?q=%22Elandon+Roberts%22",
#     "promoted_content": null,
#     "query": "%22Elandon+Roberts%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Denard Span",
#     "url": "http://twitter.com/search?q=%22Denard+Span%22",
#     "promoted_content": null,
#     "query": "%22Denard+Span%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GBvsWAS",
#     "url": "http://twitter.com/search?q=%23GBvsWAS",
#     "promoted_content": null,
#     "query": "%23GBvsWAS",
#     "tweet_volume": 11323
#    },
#    {
#     "name": "#ORLvCLB",
#     "url": "http://twitter.com/search?q=%23ORLvCLB",
#     "promoted_content": null,
#     "query": "%23ORLvCLB",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HaltandCatchFire",
#     "url": "http://twitter.com/search?q=%23HaltandCatchFire",
#     "promoted_content": null,
#     "query": "%23HaltandCatchFire",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DENvsSF",
#     "url": "http://twitter.com/search?q=%23DENvsSF",
#     "promoted_content": null,
#     "query": "%23DENvsSF",
#     "tweet_volume": null
#    },
#    {
#     "name": "#svengoolie",
#     "url": "http://twitter.com/search?q=%23svengoolie",
#     "promoted_content": null,
#     "query": "%23svengoolie",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LoveThyNeighbor",
#     "url": "http://twitter.com/search?q=%23LoveThyNeighbor",
#     "promoted_content": null,
#     "query": "%23LoveThyNeighbor",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NJvSEA",
#     "url": "http://twitter.com/search?q=%23NJvSEA",
#     "promoted_content": null,
#     "query": "%23NJvSEA",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PORvHOU",
#     "url": "http://twitter.com/search?q=%23PORvHOU",
#     "promoted_content": null,
#     "query": "%23PORvHOU",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CHIvsAZ",
#     "url": "http://twitter.com/search?q=%23CHIvsAZ",
#     "promoted_content": null,
#     "query": "%23CHIvsAZ",
#     "tweet_volume": null
#    },
#    {
#     "name": "#saturdaynight",
#     "url": "http://twitter.com/search?q=%23saturdaynight",
#     "promoted_content": null,
#     "query": "%23saturdaynight",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheManchurianCandidate",
#     "url": "http://twitter.com/search?q=%23TheManchurianCandidate",
#     "promoted_content": null,
#     "query": "%23TheManchurianCandidate",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ABigChangeForMeIs",
#     "url": "http://twitter.com/search?q=%23ABigChangeForMeIs",
#     "promoted_content": null,
#     "query": "%23ABigChangeForMeIs",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SKCvFCD",
#     "url": "http://twitter.com/search?q=%23SKCvFCD",
#     "promoted_content": null,
#     "query": "%23SKCvFCD",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NYJvsDET",
#     "url": "http://twitter.com/search?q=%23NYJvsDET",
#     "promoted_content": null,
#     "query": "%23NYJvsDET",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NEvsHOU",
#     "url": "http://twitter.com/search?q=%23NEvsHOU",
#     "promoted_content": null,
#     "query": "%23NEvsHOU",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WorldPhotoDay",
#     "url": "http://twitter.com/search?q=%23WorldPhotoDay",
#     "promoted_content": null,
#     "query": "%23WorldPhotoDay",
#     "tweet_volume": 46072
#    },
#    {
#     "name": "#dallasagainstwhitesupremacy",
#     "url": "http://twitter.com/search?q=%23dallasagainstwhitesupremacy",
#     "promoted_content": null,
#     "query": "%23dallasagainstwhitesupremacy",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LARvsOAK",
#     "url": "http://twitter.com/search?q=%23LARvsOAK",
#     "promoted_content": null,
#     "query": "%23LARvsOAK",
#     "tweet_volume": null
#    },
#    {
#     "name": "#metvstartrek",
#     "url": "http://twitter.com/search?q=%23metvstartrek",
#     "promoted_content": null,
#     "query": "%23metvstartrek",
#     "tweet_volume": null
#    },
#    {
#     "name": "#COLvDC",
#     "url": "http://twitter.com/search?q=%23COLvDC",
#     "promoted_content": null,
#     "query": "%23COLvDC",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2017-08-20T02:19:31Z",
#   "created_at": "2017-08-20T02:17:15Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# Corinthians,#Luan10,Jaylon Smith,#SignsYoureOutOfTouch,#PushAwardsKathNiels,#TFCLive,#بالروح_ياهلال_العين_مايروح,#NXTTakeOver,#GBvsWAS,#راعي_لكزس_يستعرض_بمخموره,#LaNocheDeML,#HispanicsBreakTheInternet,Wilmar,#CriancaEsperanca,Cooper Rush,Dolphin Mall,Pumas,#BOCAxESPN,インテ,Arrogate,Guede,Cerro,#LugaresQueHablan,#LosFinesSiempre,#PodemosHablar,コミティア,#CrawfordIndongo,#L6Nnotengomiedo,#لو_التقاليد_والعادات_تسمح_لي,Vinicius Jr,#ワイドナショー,#MissBrasil,Mancini,#نواف_العابد,Fabra,#MostRequestedLive,#يابشر_ملينا,#DaleAlboAlaCancha,Dick Gregory,#مزاجي_يبي_الان,#زواج_حمود_الفايز_وروي_الصبان,設営完了,Cruz Azul,#LaLigaTVN,#BakeOffBrasil,#LaNuevaOlla
# ('----------', 'us')
# Aaron Rodgers,#HaltandCatchFire,#NEvsHOU,Mahomes,#COLvDC,#SignsYoureOutOfTouch,#saturdaynight,Colts,Stage 2,Bruce Ellington,Denard Span,#LoveThyNeighbor,#LARvsOAK,#ORLvCLB,#SKCvFCD,#NXTTakeOver,#TheManchurianCandidate,#metvstartrek,#GBvsWAS,#NYJvsDET,#HispanicsBreakTheInternet,Cooper Rush,USS Indianapolis,Dolphin Mall,#DENvsSF,Devers,#CHIvsAZ,Tyler Austin,Arrogate,D'Onta Foreman,Hackenberg,#svengoolie,Tom Savage,#CrawfordIndongo,#dallasagainstwhitesupremacy,Rex Burkhead,Marlon Mack,Ross Martin,Cyrus Jones,#PORvHOU,Noah Brown,Stephen Morris,#ABigChangeForMeIs,Andre Hal,#MostRequestedLive,Dick Gregory,#NJvSEA,Elandon Roberts,#WorldPhotoDay,Shakur Stevenson
# ('----------', 'san diego')
# Aaron Rodgers,#HaltandCatchFire,#NEvsHOU,Mahomes,#SignsYoureOutOfTouch,#saturdaynight,Colts,Bruce Ellington,Denard Span,Chris Thompson,#LoveThyNeighbor,#ORLvCLB,#SKCvFCD,#D6Toss,#NXTTakeOver,#TheManchurianCandidate,#metvstartrek,#GBvsWAS,Pacific Classic,#NYJvsDET,#HispanicsBreakTheInternet,Cooper Rush,USS Indianapolis,Dolphin Mall,#DENvsSF,#CHIvsAZ,#eclipse,#WeekendCountdown,Tyler Austin,Hackenberg,#svengoolie,Tom Savage,#CrawfordIndongo,#dallasagainstwhitesupremacy,Rex Burkhead,Marlon Mack,Ross Martin,Cyrus Jones,#EatPlayLove,Noah Brown,Stephen Morris,#heel,#CruisefortheCause,Andre Hal,#MostRequestedLive,#ABigChangeForMeIs,Dick Gregory,#NW88JR,#NJvSEA,#WorldPhotoDay

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#GBvsWAS', '#HispanicsBreakTheInternet', '#MostRequestedLive', '#SignsYoureOutOfTouch', 'Cooper Rush', 'Dolphin Mall', 'Dick Gregory', '#CrawfordIndongo', '#NXTTakeOver', 'Arrogate'}
# ('==========', 'intersection of us and san-diego')
# {'Aaron Rodgers', '#HaltandCatchFire', '#NEvsHOU', 'Mahomes', '#SignsYoureOutOfTouch', '#saturdaynight', 'Colts', 'Bruce Ellington', 'Denard Span', '#LoveThyNeighbor', '#ORLvCLB', '#SKCvFCD', '#metvstartrek', '#NXTTakeOver', '#TheManchurianCandidate', '#GBvsWAS', '#NYJvsDET', '#HispanicsBreakTheInternet', 'Cooper Rush', 'USS Indianapolis', 'Dolphin Mall', '#DENvsSF', '#CHIvsAZ', 'Tyler Austin', 'Hackenberg', '#svengoolie', 'Tom Savage', '#CrawfordIndongo', '#dallasagainstwhitesupremacy', 'Rex Burkhead', 'Marlon Mack', 'Ross Martin', 'Cyrus Jones', 'Noah Brown', 'Stephen Morris', '#ABigChangeForMeIs', 'Andre Hal', '#MostRequestedLive', 'Dick Gregory', '#NJvSEA', '#WorldPhotoDay'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
topic = '#GBvsWAS' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=topic, count=number)

statuses = search_results['statuses']

# %%
print(len(statuses))
print(statuses[:1])
# Out:
# 100
# [{'created_at': 'Sun Aug 20 02:28:54 +0000 2017', 'id': 899095871412981760, 'id_str': '899095871412981760', 'text': 'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6', 'truncated': False, 'entities': {'hashtags': [{'text': 'GBvsWAS', 'indices': [55, 63]}, {'text': 'GoPackGo', 'indices': [64, 73]}], 'symbols': [], 'user_mentions': [{'screen_name': 'packers', 'name': 'Green Bay Packers', 'id': 35865630, 'id_str': '35865630', 'indices': [3, 11]}, {'screen_name': 'T_Hill4', 'name': 'Taysom Hill', 'id': 1061228834, 'id_str': '1061228834', 'indices': [35, 43]}], 'urls': [], 'media': [{'id': 899095289067446273, 'id_str': '899095289067446273', 'indices': [74, 97], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg', 'url': 'https://t.co/X2rbnV7qr6', 'display_url': 'pic.twitter.com/X2rbnV7qr6', 'expanded_url': 'https://twitter.com/packers/status/899095663887224833/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 566, 'h': 282, 'resize': 'fit'}, 'large': {'w': 566, 'h': 282, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 340, 'h': 169, 'resize': 'fit'}}, 'source_status_id': 899095663887224833, 'source_status_id_str': '899095663887224833', 'source_user_id': 35865630, 'source_user_id_str': '35865630'}]}, 'extended_entities': {'media': [{'id': 899095289067446273, 'id_str': '899095289067446273', 'indices': [74, 97], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg', 'url': 'https://t.co/X2rbnV7qr6', 'display_url': 'pic.twitter.com/X2rbnV7qr6', 'expanded_url': 'https://twitter.com/packers/status/899095663887224833/photo/1', 'type': 'animated_gif', 'sizes': {'medium': {'w': 566, 'h': 282, 'resize': 'fit'}, 'large': {'w': 566, 'h': 282, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 340, 'h': 169, 'resize': 'fit'}}, 'source_status_id': 899095663887224833, 'source_status_id_str': '899095663887224833', 'source_user_id': 35865630, 'source_user_id_str': '35865630', 'video_info': {'aspect_ratio': [283, 141], 'variants': [{'bitrate': 0, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/tweet_video/DHo6ZtwXoAEfCV8.mp4'}]}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 187045811, 'id_str': '187045811', 'name': 'Doreen Workman', 'screen_name': 'dw2curley', 'location': 'Edmond, WV ', 'description': "Packers Fan for Life🏈\nAn amateur photographer, I see beauty in everything. I Look for the bright side in life it's there sometimes it takes awhile to find it😁", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 239, 'friends_count': 501, 'listed_count': 7, 'created_at': 'Sun Sep 05 03:10:26 +0000 2010', 'favourites_count': 9392, 'utc_offset': -14400, 'time_zone': 'Eastern Time (US & Canada)', 'geo_enabled': True, 'verified': False, 'statuses_count': 10352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/716714818829352961/OSHZmTd1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/716714818829352961/OSHZmTd1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/187045811/1431911740',  ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 34

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: Geronimo! \n\n#GBvsWAS #GoPackGo https://t.co/4cRkPXbBhh',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @Redskins: Colt put it where only Niles could get to it. #HTTR\n\nMore #GBvsWAS highlights: https://t.co/4ZCAncxGbV https://t.co/yaKJnS4Kem',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @Redskins: Pete Robertson getting after the QB! #HTTR #GBvsWAS https://t.co/DcdEGJyxhW',
#  'RT @Redskins: No. 2️⃣4️⃣. From @CoastalFootball. Josh. NORMAN! #GBvsWAS https://t.co/Abc5682qGr',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @Redskins: Colt put it where only Niles could get to it. #HTTR\n\nMore #GBvsWAS highlights: https://t.co/4ZCAncxGbV https://t.co/yaKJnS4Kem',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'Can the #Redskins 3rd string QB match the GB Score? #RedskinsNation #HTTR #GBvsWAS #GreenBayPackers',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'Touchdown!!!!! @T_Hill4 #GoPackGo🏈 #GBvsWAS',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'love how excited Rodgers was about that last TD #GBvsWAS',
#  'RT @Redskins: #Redskins take a lead into the 4th! #HTTR \n\n#GBvsWAS Update: https://t.co/RLwgeOH79Q https://t.co/ESgFO4kmPH',
#  "RT @TMatich: #Packers @T_Hill4 scrambles for TD. Looks a little like Steve, doesn't he! #GBvsWAS #BYU @BYUSportsNation #HTTR",
#  'RT @packers: Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'The #Packers kicked the extra point to increase their score to 21. They lead by 4. #GBvsWAS #HTTR\n\n#WAS - 17 #GB - 21, 4th quarter',
#  "RT @TMatich: #Packers @T_Hill4 scrambles for TD. Looks a little like Steve, doesn't he! #GBvsWAS #BYU @BYUSportsNation #HTTR",
#  'Back on top after the @T_Hill4 TD run! 🙌\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6',
#  'https://t.co/9rFtvUaVQ1 #SignsYoureOutOfTouch #HispanicsBreakTheInternet #MostRequestedLive #NXTTakeOver #GBvsWAS… https://t.co/69sCHKF6g0',
#  'RT @packers: Kentrell Brice breaks up the deep ball from Colt McCoy #GBvsWAS #GoPackGo',
#  'RT @RedskinsCR: To kick-off #PlayFootball month, we hosted @duvalhigh on-field for the anthem! #HTTR #GBvsWAS 🇺🇸🏈 https://t.co/zxozKySBNw',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: The QB. \n\n#GBvsWAS #GoPackGo https://t.co/3DkDEZgZAY',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @Redskins: Nate Sudfeld is in at QB for the #Redskins. #HTTR #GBvsWAS',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  "#Packers @T_Hill4 scrambles for TD. Looks a little like Steve, doesn't he! #GBvsWAS #BYU @BYUSportsNation #HTTR",
#  'RT @Redskins: #Redskins trail the Packers after one. #HTTR #GBvsWAS https://t.co/Rx6wRpHpoi',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  "RT @packers: Let's go! \n\n#GoPackGo #GBvsWAS https://t.co/UvIbuxjqZ8",
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @RedskinsCR: To kick-off #PlayFootball month, we hosted @duvalhigh on-field for the anthem! #HTTR #GBvsWAS 🇺🇸🏈 https://t.co/zxozKySBNw',
#  "HOT TAKE: Taysom Hill makes the 53, don't @ me #GBvsWAS",
#  'RT @packers: The #Packers win the toss and defer #GBvsWAS #GoPackGo',
#  'TAYSOM!!!! 🏈🏈🙌🏻🙌🏻🙌🏻 @T_Hill4 #GBvsWAS @packers',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: Geronimo! \n\n#GBvsWAS #GoPackGo https://t.co/4cRkPXbBhh',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @NFL: .@aaronrodgers12 on the MOVE! 🏃💨 #GBvsWAS https://t.co/DuSOy5g4F1',
#  'RT @packers: PREGAME HYPE ‼️\n\n#GBvsWAS #GoPackGo https://t.co/ltrPEufU7g',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'Taysom Hill, que homão da porra. #GoPackGo #GBvsWAS',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'Geoff Gray, holding up for just long enough @cflsuperagent #GBvsWAS https://t.co/qUXBzvl7kE',
#  'RT @Redskins: Colt put it where only Niles could get to it. #HTTR\n\nMore #GBvsWAS highlights: https://t.co/4ZCAncxGbV https://t.co/yaKJnS4Kem',
#  '@T_Hill4 we see you 👀 #GoPackGo 🏈💚💛🧀 #GBvsWAS',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT packers ".T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/JQhRZ1xXHH"',
#  'RT @packers: Geronimo! \n\n#GBvsWAS #GoPackGo https://t.co/4cRkPXbBhh',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'https://t.co/m4OZl3cnaM #heel #INDvsDAL #LameCultRituals #NXTakeOverBrooklynIII #Eclipse #Dope200M #NotATarget #SCFCvAFC #stanEXO #GBvsWAS',
#  "We're up 21-17. #GBvsWAS",
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @Redskins: #Redskins take a lead into the 4th! #HTTR \n\n#GBvsWAS Update: https://t.co/RLwgeOH79Q https://t.co/ESgFO4kmPH',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @Redskins: Cousins ➡️ Crowder connection. #HTTR\n\nMore #GBvsWAS highlights: https://t.co/4ZCAncxGbV https://t.co/boqUrMYN73',
#  'White boy got some wheels 👀🏃🏼 #GBvsWAS',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @Redskins: Colt put it where only Niles could get to it. #HTTR\n\nMore #GBvsWAS highlights: https://t.co/4ZCAncxGbV https://t.co/yaKJnS4Kem',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB',
#  'RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sun Aug 20 02:28:54 +0000 2017",
#  "id": 899095871412981760,
#  "id_str": "899095871412981760",
#  "text": "RT @packers: Back on top after the @T_Hill4 TD run! \ud83d\ude4c\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "GBvsWAS",
#     "indices": [
#      55,
#      63
#     ]
#    },
#    {
#     "text": "GoPackGo",
#     "indices": [
#      64,
#      73
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "packers",
#     "name": "Green Bay Packers",
#     "id": 35865630,
#     "id_str": "35865630",
#     "indices": [
#      3,
#      11
#     ]
#    },
#    {
#     "screen_name": "T_Hill4",
#     "name": "Taysom Hill",
#     "id": 1061228834,
#     "id_str": "1061228834",
#     "indices": [
#      35,
#      43
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 899095289067446273,
#     "id_str": "899095289067446273",
#     "indices": [
#      74,
#      97
#     ],
#     "media_url": "http://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg",
#     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg",
#     "url": "https://t.co/X2rbnV7qr6",
#     "display_url": "pic.twitter.com/X2rbnV7qr6",
#     "expanded_url": "https://twitter.com/packers/status/899095663887224833/photo/1",
#     "type": "photo",
#     "sizes": {
#      "medium": {
#       "w": 566,
#       "h": 282,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 566,
#       "h": 282,
#       "resize": "fit"
#      },
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 340,
#       "h": 169,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 899095663887224833,
#     "source_status_id_str": "899095663887224833",
#     "source_user_id": 35865630,
#     "source_user_id_str": "35865630"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 899095289067446273,
#     "id_str": "899095289067446273",
#     "indices": [
#      74,
#      97
#     ],
#     "media_url": "http://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg",
#     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg",
#     "url": "https://t.co/X2rbnV7qr6",
#     "display_url": "pic.twitter.com/X2rbnV7qr6",
#     "expanded_url": "https://twitter.com/packers/status/899095663887224833/photo/1",
#     "type": "animated_gif",
#     "sizes": {
#      "medium": {
#       "w": 566,
#       "h": 282,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 566,
#       "h": 282,
#       "resize": "fit"
#      },
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 340,
#       "h": 169,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 899095663887224833,
#     "source_status_id_str": "899095663887224833",
#     "source_user_id": 35865630,
#     "source_user_id_str": "35865630",
#     "video_info": {
#      "aspect_ratio": [
#       283,
#       141
#      ],
#      "variants": [
#       {
#        "bitrate": 0,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/tweet_video/DHo6ZtwXoAEfCV8.mp4"
#       }
#      ]
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 187045811,
#   "id_str": "187045811",
#   "name": "Doreen Workman",
#   "screen_name": "dw2curley",
#   "location": "Edmond, WV ",
#   "description": "Packers Fan for Life\ud83c\udfc8\nAn amateur photographer, I see beauty in everything. I Look for the bright side in life it's there sometimes it takes awhile to find it\ud83d\ude01",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 239,
#   "friends_count": 501,
#   "listed_count": 7,
#   "created_at": "Sun Sep 05 03:10:26 +0000 2010",
#   "favourites_count": 9392,
#   "utc_offset": -14400,
#   "time_zone": "Eastern Time (US & Canada)",
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 10352,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/716714818829352961/OSHZmTd1_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/716714818829352961/OSHZmTd1_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/187045811/1431911740",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sun Aug 20 02:28:05 +0000 2017",
#   "id": 899095663887224833,
#   "id_str": "899095663887224833",
#   "text": "Back on top after the @T_Hill4 TD run! \ud83d\ude4c\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "GBvsWAS",
#      "indices": [
#       42,
#       50
#      ]
#     },
#     {
#      "text": "GoPackGo",
#      "indices": [
#       51,
#       60
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "T_Hill4",
#      "name": "Taysom Hill",
#      "id": 1061228834,
#      "id_str": "1061228834",
#      "indices": [
#       22,
#       30
#      ]
#     }
#    ],
#    "urls": [],
#    "media": [
#     {
#      "id": 899095289067446273,
#      "id_str": "899095289067446273",
#      "indices": [
#       61,
#       84
#      ],
#      "media_url": "http://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg",
#      "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg",
#      "url": "https://t.co/X2rbnV7qr6",
#      "display_url": "pic.twitter.com/X2rbnV7qr6",
#      "expanded_url": "https://twitter.com/packers/status/899095663887224833/photo/1",
#      "type": "photo",
#      "sizes": {
#       "medium": {
#        "w": 566,
#        "h": 282,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 566,
#        "h": 282,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 340,
#        "h": 169,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 899095289067446273,
#      "id_str": "899095289067446273",
#      "indices": [
#       61,
#       84
#      ],
#      "media_url": "http://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg",
#      "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DHo6ZtwXoAEfCV8.jpg",
#      "url": "https://t.co/X2rbnV7qr6",
#      "display_url": "pic.twitter.com/X2rbnV7qr6",
#      "expanded_url": "https://twitter.com/packers/status/899095663887224833/photo/1",
#      "type": "animated_gif",
#      "sizes": {
#       "medium": {
#        "w": 566,
#        "h": 282,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 566,
#        "h": 282,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 340,
#        "h": 169,
#        "resize": "fit"
#       }
#      },
#      "video_info": {
#       "aspect_ratio": [
#        283,
#        141
#       ],
#       "variants": [
#        {
#         "bitrate": 0,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/tweet_video/DHo6ZtwXoAEfCV8.mp4"
#        }
#       ]
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 35865630,
#    "id_str": "35865630",
#    "name": "Green Bay Packers",
#    "screen_name": "packers",
#    "location": "Green Bay, WI",
#    "description": "The official Twitter account of the 13-time World Champion Green Bay Packers. Super Bowl Champions I, II, XXXI, XLV.",
#    "url": "http://t.co/SOkNpLbeMb",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/SOkNpLbeMb",
#        "expanded_url": "http://www.packers.com",
#        "display_url": "packers.com",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 1883880,
#    "friends_count": 121,
#    "listed_count": 9820,
#    "created_at": "Mon Apr 27 21:22:16 +0000 2009",
#    "favourites_count": 427,
#    "utc_offset": -18000,
#    "time_zone": "Central Time (US & Canada)",
#    "geo_enabled": true,
#    "verified": true,
#    "statuses_count": 47328,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "2A433A",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/570723155606380544/BJNjh3-H.jpeg",
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/570723155606380544/BJNjh3-H.jpeg",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/856549987697733632/4s096MPz_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/856549987697733632/4s096MPz_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/35865630/1501434835",
#    "profile_link_color": "2A433A",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "DDFFCC",
#    "profile_text_color": "333333",
#    "profile_use_background_image": false,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 31,
#   "favorite_count": 93,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 31,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 31
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @packers: Back on top after the @T_Hill4 TD run! \ud83d\ude4c\n\n#GBvsWAS #GoPackGo https://t.co/X2rbnV7qr6",
#  "RT @packers: .@T_Hill4 scrambles for a 23-yard TD and the #Packers retake the lead! #GBvsWAS #GoPackGo https://t.co/Ug1XZd00CB",
#  "RT @packers: Geronimo! \n\n#GBvsWAS #GoPackGo https://t.co/4cRkPXbBhh",
#  "RT @Redskins: Colt put it where only Niles could get to it. #HTTR\n\nMore #GBvsWAS highlights: https://t.co/4ZCAncxGbV https://t.co/yaKJnS4Kem",
#  "RT @Redskins: Pete Robertson getting after the QB! #HTTR #GBvsWAS https://t.co/DcdEGJyxhW"
# ]
# [
#  "packers",
#  "T_Hill4",
#  "packers",
#  "T_Hill4",
#  "packers"
# ]
# [
#  "GBvsWAS",
#  "GoPackGo",
#  "Packers",
#  "GBvsWAS",
#  "GoPackGo"
# ]
# [
#  "RT",
#  "@packers:",
#  "Back",
#  "on",
#  "top"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#GBvsWAS', 33), ('RT', 19), ('the', 18), ('#GoPackGo', 12), ('#HTTR', 11), ('@packers:', 8), ('@T_Hill4', 7), ('for', 7), ('@Redskins:', 7), ('#Packers', 6)]
#
# [('packers', 9), ('T_Hill4', 8), ('Redskins', 7), ('BYUSportsNation', 2), ('CoastalFootball', 1), ('TMatich', 1), ('RedskinsCR', 1), ('duvalhigh', 1), ('NFL', 1), ('AaronRodgers12', 1)]
#
# [('GBvsWAS', 34), ('GoPackGo', 13), ('HTTR', 11), ('Packers', 6), ('Redskins', 4), ('BYU', 2), ('RedskinsNation', 1), ('GreenBayPackers', 1), ('WAS', 1), ('GB', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# #GBvsWAS             |     33
# RT                   |     19
# the                  |     18
# #GoPackGo            |     12
# #HTTR                |     11
# @packers:            |      8
# @T_Hill4             |      7
# for                  |      7
# @Redskins:           |      7
# #Packers             |      6
#
#     Screen Name      | Count
# ****************************************
# packers              |      9
# T_Hill4              |      8
# Redskins             |      7
# BYUSportsNation      |      2
# CoastalFootball      |      1
# TMatich              |      1
# RedskinsCR           |      1
# duvalhigh            |      1
# NFL                  |      1
# AaronRodgers12       |      1
#
#       Hashtag        | Count
# ****************************************
# GBvsWAS              |     34
# GoPackGo             |     13
# HTTR                 |     11
# Packers              |      6
# Redskins             |      4
# BYU                  |      2
# RedskinsNation       |      1
# GreenBayPackers      |      1
# WAS                  |      1
# GB                   |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#   533   |     packers     | RT @packers: The QB. \\#GBvsWAS #GoPackGo https://
#         |                 | t.co/3DkDEZgZAY
#   284   |    Redskins     | RT @Redskins: No. 2️⃣4️⃣. From @CoastalFootball. J
#         |                 | osh. NORMAN! #GBvsWAS https://t.co/Abc5682qGr
#   249   |     packers     | RT @packers: PREGAME HYPE ‼️\\#GBvsWAS #GoPackGo h
#         |                 | ttps://t.co/ltrPEufU7g
#   208   |     packers     | RT @packers: Geronimo! \\#GBvsWAS #GoPackGo https:
#         |                 | //t.co/4cRkPXbBhh
#   178   |     packers     | RT @packers: Let's go! \\#GoPackGo #GBvsWAS https:
#         |                 | //t.co/UvIbuxjqZ8
#   167   |       NFL       | RT @NFL: .@aaronrodgers12 on the MOVE! 🏃💨 #GBvsWAS
#         |                 |  https://t.co/DuSOy5g4F1
#   110   |     packers     | RT @packers: .@T_Hill4 scrambles for a 23-yard TD
#         |                 | and the #Packers retake the lead! #GBvsWAS #GoPack
#         |                 | Go https://t.co/Ug1XZd00CB
#   89    |    Redskins     | RT @Redskins: Cousins ➡️ Crowder connection. #HTTR
#         |                 | \\More #GBvsWAS highlights: https://t.co/4ZCAncxGb
#         |                 | V https://t.co/boqUrMYN73
#   85    |    Redskins     | RT @Redskins: Colt put it where only Niles could g
#         |                 | et to it. #HTTR\\More #GBvsWAS highlights: https:/
#         |                 | /t.co/4ZCAncxGbV https://t.co/yaKJnS4Kem
#   53    |    Redskins     | RT @Redskins: #Redskins take a lead into the 4th!
#         |                 | #HTTR \\#GBvsWAS Update: https://t.co/RLwgeOH79Q h
#         |                 | ttps://t.co/ESgFO4kmPH
